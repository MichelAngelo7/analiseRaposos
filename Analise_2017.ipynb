# %%
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
# importação dos dados
dataset = pd.read_csv("./dados/Despesas_Credor_2017.csv", sep=";")
#visualização
dataset.head()
# Out:
#                             Exportado em: 11/09/2020 Unnamed: 1 Unnamed: 2  \
# 0                                       Raposos - MG        NaN        NaN
# 1                    PREFEITURA MUNICIPAL DE RAPOSOS        NaN        NaN
# 2                                Despesas por credor        NaN        NaN
# 3  Filtros utilizados para elaboração da consulta...        NaN        NaN
# 4                                Despesas por credor        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4                               Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN                                      NaN        NaN
# 1        NaN        NaN                                      NaN        NaN
# 2        NaN        NaN  Última atualização: 11/09/2020 11:39:36        NaN
# 3        NaN        NaN                                      NaN        NaN
# 4        NaN        NaN                                      NaN        NaN
#
#   Unnamed: 7  Transparência Fly Unnamed: 9
# 0        NaN                NaN        NaN
# 1        NaN                NaN        NaN
# 2        NaN                NaN        NaN
# 3        NaN                NaN        NaN
# 4        NaN                NaN        NaN

# %%
# tamanho
dataset.shape
# Out:
# (125, 10)

# %%
dataset = dataset.drop([0,1,2,3,4,5])

# %%
dataset.head()
# Out:
#                      Exportado em: 11/09/2020 Unnamed: 1  Unnamed: 2  \
# 6                  3 PODERES COMERCIO LTDA ME       0,00       40,80
# 7        ACACIA COMERCIO DE MEDICAMENTOS LTDA       0,00  251.008,72
# 8   ACCUMED PRODUTOS MEDICO HOSPITALARES LTDA       0,00      700,00
# 9    ACTCON COMÉRCIO DE PRODUTOS DE INFORMÁTI       0,00      525,00
# 10           ADILENE ANASTACIA FRANCISCO - ME       0,00    1.980,00
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Transparência Fly  \
# 6        0,00       0,00        NaN       0,00       0,00                NaN
# 7        0,00       0,00        NaN       0,00       0,00                NaN
# 8        0,00       0,00        NaN       0,00       0,00                NaN
# 9        0,00       0,00        NaN       0,00       0,00                NaN
# 10       0,00       0,00        NaN       0,00       0,00                NaN
#
#     Unnamed: 9
# 6        40,80
# 7   251.008,72
# 8       700,00
# 9       525,00
# 10    1.980,00

# %%
dataset.columns = ['creador', 'Pagamentos do ano (a) (R$)', 'Saldo a pagar do ano (b) (R$)', 'Pagamento de restos (c) (R$)',
                   'Saldo de restos a pagar (d) (R$)','Sem nome 1','Cancelamento de restos (R$)', 
                   'Pagamento total (a + c) (R$)','Sem Nome 2','Saldo a pagar (b + d) (R$)']

# %%
dataset.head()
# Out:
#                                       creador Pagamentos do ano (a) (R$)  \
# 6                  3 PODERES COMERCIO LTDA ME                       0,00
# 7        ACACIA COMERCIO DE MEDICAMENTOS LTDA                       0,00
# 8   ACCUMED PRODUTOS MEDICO HOSPITALARES LTDA                       0,00
# 9    ACTCON COMÉRCIO DE PRODUTOS DE INFORMÁTI                       0,00
# 10           ADILENE ANASTACIA FRANCISCO - ME                       0,00
#
#    Saldo a pagar do ano (b) (R$) Pagamento de restos (c) (R$)  \
# 6                          40,80                         0,00
# 7                     251.008,72                         0,00
# 8                         700,00                         0,00
# 9                         525,00                         0,00
# 10                      1.980,00                         0,00
#
#    Saldo de restos a pagar (d) (R$) Sem nome 1 Cancelamento de restos (R$)  \
# 6                              0,00        NaN                        0,00
# 7                              0,00        NaN                        0,00
# 8                              0,00        NaN                        0,00
# 9                              0,00        NaN                        0,00
# 10                             0,00        NaN                        0,00
#
#    Pagamento total (a + c) (R$)  Sem Nome 2 Saldo a pagar (b + d) (R$)
# 6                          0,00         NaN                      40,80
# 7                          0,00         NaN                 251.008,72
# 8                          0,00         NaN                     700,00
# 9                          0,00         NaN                     525,00
# 10                         0,00         NaN                   1.980,00

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 6 to 124
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   creador                           119 non-null    object
#  1   Pagamentos do ano (a) (R$)        119 non-null    object
#  2   Saldo a pagar do ano (b) (R$)     119 non-null    object
#  3   Pagamento de restos (c) (R$)      119 non-null    object
#  4   Saldo de restos a pagar (d) (R$)  119 non-null    object
#  5   Sem nome 1                        0 non-null      object
#  6   Cancelamento de restos (R$)       119 non-null    object
#  7   Pagamento total (a + c) (R$)      119 non-null    object
#  8   Sem Nome 2                        0 non-null      float64
#  9   Saldo a pagar (b + d) (R$)        119 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 10.2+ KB

# %%
dataset['Saldo a pagar do ano (b) (R$)'] = dataset['Saldo a pagar do ano (b) (R$)'].apply(lambda x: str(x).replace(',','.'))

# %%
dataset['Saldo a pagar do ano (b) (R$)']
# Out:
# 6                40.80
# 7           251.008.72
# 8               700.00
# 9               525.00
# 10            1.980.00
#             ...
# 120           3.293.09
# 121          12.815.00
# 122             753.97
# 123           4.601.56
# 124    R$ 1.599.472.37
# Name: Saldo a pagar do ano (b) (R$), Length: 119, dtype: object

# %%
dataset['Saldo a pagar do ano (b) (R$)'] = dataset['Saldo a pagar do ano (b) (R$)'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-db495f56f29d> in <module>
# ----> 1 dataset['Saldo a pagar do ano (b) (R$)'] = dataset['Saldo a pagar do ano (b) (R$)'].astype('float64')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     895     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     896         # Explicit copy, or required since NumPy can't view from / to object.
# --> 897         return arr.astype(dtype, copy=True)
#     898
#     899     return arr.view(dtype)
#
# ValueError: could not convert string to float: '251.008.72'

# %%
#Pagamentos do ano (a) (R$)
dataset['Pagamentos do ano (a) (R$)'].describe()

# %%
srn.boxplot(dataset['Pagamentos do ano (a) (R$)']).set_title('Pagamentos do ano (a) (R$)')
